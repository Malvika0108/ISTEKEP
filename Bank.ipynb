# %%
class BankAccount:
    def __init__(self):
        self.custname = ""
        self.balance = 0
        self.empname = ""
        self.empid = 0
        self.cust_phone = 0
        
    def add_customer(self):
        self.custname = input("Enter name of customer = ")
        self.balance= float(input("Enter amount to be deposited = "))
        self.cust_phone = input("Enter customer phone number = ")
    
    def add_employee(self):
        self.empname = input("Enter employee name = ")
        self.empid = input("Enter employee id = ")
        
    def updateaccdetails(self):
        print("Enter new account details")
        custname = input("Enter name of customer = ")
        cust_phone = input("Enter customer phone number = ")
        
    def deposit(self):
        amount=float(input("Enter amount to be Deposited: "))
        self.balance += amount
        print("\n Amount Deposited:",amount)
    
    def withdraw(self):
        amount = float(input("Enter amount to be withdrawn: "))
        if self.balance >= amount:
            self.balance -= amount
            print("\n You Withdrew:", amount)
        else:
            print("\n Insufficient balance  ")
    
    def balancecheck(self):
        print("BALANCE = ", self.balance)
        
    def display(self):
        print("\nCustomer name = ", self.custname, "\nPhone Number = ",self.cust_phone,"\nBalance = ",self.balance)
           
s=BankAccount()
c=int(input("Welcome to the bank\nWhat would you like to do ?\n1.Create new customer account\n2.Create new employee account"))
if(c==1):
    s.add_customer()
else:
    s.add_employee
c=int(input("\n1.Deposit cash\n2.Withdraw cash\n3.Update Account Details\n4.View Balance"))
if(c==1):
    s.deposit()
if(c==2):
    s.withdraw()
if(c==3):
    s.updateaccdetails()
if(c==4):
    s.balancecheck()
s.display()
# Out:
# Welcome to the bank
# What would you like to do ?
# 1.Create new customer account
# 2.Create new employee account1
# Enter name of customer = mali
# Enter amount to be deposited = 100000
# Enter customer phone number = 23982390443
#
# 1.Deposit cash
# 2.Withdraw cash
# 3.Update Account Details
# 4.View Balance2
# Enter amount to be withdrawn: 100
#
#  You Withdrew: 100.0
#
# Customer name =  mali
# Phone Number =  23982390443
# Balance =  99900.0
